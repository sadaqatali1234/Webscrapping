# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=98f31e31-51ed-4486-9f6e-d280500330cb"

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.07395f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
soup=BeautifulSoup(res.content,"html.parser")

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
title=soup.title

# %%
title
# Out:
# <title>Mobiles- Buy Products Online at Best Price in India - All Categories | Flipkart.com</title>

# %%
anchors=soup.find_all("a")

# %%
anchors
all_links=set()
for link in anchors:
    if (link.get("href")!="#"):
        all_links.add("https://www.flipkart.com/search?q=mobiles&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_1_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_1_0_na_na_na&as-pos=1&as-type=TRENDING&suggestionId=mobiles&requestId=98f31e31-51ed-4486-9f6e-d280500330cb"+link.get("href"))

# %%
links=pd.DataFrame(all_links)

# %%
links.rename(columns={0:"Webpages"},inplace=True)

# %%
links.head()
# Out:
#                                             Webpages
# 0  https://www.flipkart.com/search?q=mobiles&as=o...
# 1  https://www.flipkart.com/search?q=mobiles&as=o...
# 2  https://www.flipkart.com/search?q=mobiles&as=o...
# 3  https://www.flipkart.com/search?q=mobiles&as=o...
# 4  https://www.flipkart.com/search?q=mobiles&as=o...

# %%
links.iloc[0]
# Out:
# Webpages    https://www.flipkart.com/search?q=mobiles&as=o...
# Name: 0, dtype: object

# %%
img=soup.find_all("img")

# %%
img
# Out:
# [<img alt="Flipkart" class="_2xm1JU" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_8d85f4.png" title="Flipkart" width="75"/>,
#  <img src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/plus_aef861.png" width="10"/>,
#  <img class="_3U-Vxu" height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"/>,
#  <img alt="Buying Guide" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_4dd325.png"/>,
#  <img alt="REDMI 9i (Midnight Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kesv0y80/mobile/h/p/q/redmi-9i-mzb0814in-original-imafvehkgzghyqtp.jpeg?q=70"/>,
#  <img class="_1wB99o" src="..."/>,
#  <img height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"/>,
# ...

# %%
all_img=set()
for i in img:
    all_img.add(i['src'])
    #if (i.get("img src") !=#):
       # print("a")

# %%
im = pd.DataFrame(all_img)

# %%
im.rename(columns={0:"image soruce code"})
# Out:
#                                     image soruce code
# 0   https://rukminim1.flixcart.com/image/312/312/k...
# 1   ......
# 2   https://rukminim1.flixcart.com/image/312/312/k...
# 3   https://rukminim1.flixcart.com/image/312/312/k...
# 4   https://rukminim1.flixcart.com/image/312/312/k...
# 5   ......
# 6   https://rukminim1.flixcart.com/image/312/312/k...
# 7   https://rukminim1.flixcart.com/image/312/312/k...
# 8   https://rukminim1.flixcart.com/image/312/312/k...
# 9   //static-assets-web.flixcart.com/www/linchpin/...
# 10  https://rukminim1.flixcart.com/image/312/312/k...
# 11  https://rukminim1.flixcart.com/image/312/312/k...
# 12  https://rukminim1.flixcart.com/image/312/312/k...
# 13  //static-assets-web.flixcart.com/www/linchpin/...
# 14  https://rukminim1.flixcart.com/image/312/312/k...
# 15  https://rukminim1.flixcart.com/image/312/312/k...
# 16  //static-assets-web.flixcart.com/www/linchpin/...
# 17  https://rukminim1.flixcart.com/image/312/312/k...
# ...

# %%
im.iloc[22]
# Out:
# 0    //static-assets-web.flixcart.com/www/linchpin/...
# Name: 22, dtype: object

# %%
import os

# %%
os.mkdir("img_scraping")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-23-2b88445e73ff> in <module>
# ----> 1 os.mkdir("img_scraping")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'img_scraping'

# %%
i=1
for index,img in enumerate(all_img):
    print(img)
    #if i <= 10:
        #img_data=requests.get(img).content

# %%
img_1=soup.select("img[src^="//rukminim1.flixcart.com/image/312/312"]")
# Out:
#   File "<ipython-input-28-0c8d869edbc3>", line 1
#     img_1=soup.select("img[src^="//rukminim1.flixcart.com/image/312/312"]")
#                                                                          ^
# SyntaxError: invalid syntax

# %%
help(soup.select)
